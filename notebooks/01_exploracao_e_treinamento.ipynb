# %% [markdown]
# ## 1. Importação de Bibliotecas

# %%
import os
import sys
import json
import joblib
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import yfinance as yf
import tensorflow as tf
import matplotlib.pyplot as plt

from datetime import datetime, timedelta
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

np.random.seed(42)
tf.random.set_seed(42)

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 1.26.3
# Pandas version: 2.1.4

# %% [markdown]
# ## 2. Coleta de Dados
#
# Utilizamos a biblioteca `yfinance` para obter dados históricos da **PETR4.SA** (Petrobras) na B3.

# %%
# Configuração da coleta
SYMBOL = 'PETR4.SA'  # Petrobras
START_DATE = '2018-01-01'  
END_DATE = datetime.now().strftime('%Y-%m-%d')

print(f"Coletando dados de {SYMBOL}")
print(f"Período: {START_DATE} até {END_DATE}")
print("-" * 50)

# Download dos dados
df = yf.download(SYMBOL, start=START_DATE, end=END_DATE, progress=True) 

# Remove MultiIndex se existir
if isinstance(df.columns, pd.MultiIndex):
    df.columns = df.columns.get_level_values(0)

print(f"\n✓ Dados coletados: {len(df)} registros")
print(f"  Período real: {df.index.min().date()} até {df.index.max().date()}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Coletando dados de PETR4.SA
# Período: 2018-01-01 até 2026-01-05
# --------------------------------------------------
#
# ✓ Dados coletados: 1989 registros
#   Período real: 2018-01-02 até 2026-01-02

# %%
# Visualização inicial dos dados
print("Primeiras linhas:")
display(df.head())

print("\nÚltimas linhas:")
display(df.tail())

print("\nInformações do DataFrame:")
df.info()
# Out:
# Primeiras linhas:
# Price          Close      High       Low      Open    Volume
# Date
# 2018-01-02  4.410662  4.410662  4.314721  4.314721  33461800
# 2018-01-03  4.450639  4.455969  4.362693  4.394673  55940900
# 2018-01-04  4.458633  4.519930  4.429318  4.471959  37064900
# 2018-01-05  4.485283  4.493279  4.415992  4.450638  26958200
# 2018-01-08  4.538586  4.538586  4.453304  4.461299  28400000
# Últimas linhas:
# Price           Close       High        Low       Open    Volume
# Date
# 2025-12-23  30.309999  30.570000  30.200001  30.549999  35703900
# 2025-12-26  30.410000  30.430000  30.120001  30.309999  20178600
# 2025-12-29  30.730000  30.809999  30.520000  30.559999  20588100
# 2025-12-30  30.820000  30.959999  30.650000  30.799999  16880600
# 2026-01-02  30.709999  30.959999  30.360001  30.959999  21625200
# Informações do DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1989 entries, 2018-01-02 to 2026-01-02
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   1989 non-null   float64
#  1   High    1989 non-null   float64
#  2   Low     1989 non-null   float64
#  3   Open    1989 non-null   float64
#  4   Volume  1989 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 93.2 KB

# %%
# Estatísticas descritivas
print("Estatísticas Descritivas:")
display(df.describe())
# Out:
# Estatísticas Descritivas:
# Price        Close         High          Low         Open        Volume
# count  1989.000000  1989.000000  1989.000000  1989.000000  1.989000e+03
# mean     15.279440    15.471062    15.091187    15.283488  6.063574e+07
# std       9.996219    10.077063     9.919477     9.998600  3.544502e+07
# min       3.243089     3.498744     3.116698     3.179894  0.000000e+00
# 25%       7.100594     7.206238     6.992488     7.104574  3.664340e+07
# 50%      10.478977    10.620348    10.351748    10.436567  5.358550e+07
# 75%      26.827408    27.164582    26.504897    26.796095  7.446100e+07
# max      34.581184    34.724902    34.410525    34.608133  4.902304e+08

# %% [markdown]
# ## 3. Feature Engineering - Indicadores Técnicos
#
# Para melhorar o modelo, vamos adicionar indicadores técnicos que capturam diferentes aspectos do comportamento do mercado:
#
# - **RSI** (Relative Strength Index): Momentum
# - **MACD**: Tendência
# - **Bollinger Bands**: Volatilidade
# - **ATR** (Average True Range): Volatilidade
# - **Retornos Logarítmicos**: Variação normalizada

# %%
def add_technical_indicators(df):
    """
    Adiciona indicadores técnicos ao DataFrame.
    """
    df = df.copy()
    
    # RSI (Relative Strength Index) - 14 períodos
    delta = df['Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=14).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=14).mean()
    rs = gain / loss
    df['RSI'] = 100 - (100 / (1 + rs))
    
    # MACD (Moving Average Convergence Divergence)
    exp1 = df['Close'].ewm(span=12, adjust=False).mean()
    exp2 = df['Close'].ewm(span=26, adjust=False).mean()
    df['MACD'] = exp1 - exp2
    df['MACD_Signal'] = df['MACD'].ewm(span=9, adjust=False).mean()
    df['MACD_Hist'] = df['MACD'] - df['MACD_Signal']
    
    # Bollinger Bands
    df['BB_Middle'] = df['Close'].rolling(window=20).mean()
    bb_std = df['Close'].rolling(window=20).std()
    df['BB_Upper'] = df['BB_Middle'] + (bb_std * 2)
    df['BB_Lower'] = df['BB_Middle'] - (bb_std * 2)
    df['BB_Width'] = (df['BB_Upper'] - df['BB_Lower']) / df['BB_Middle']
    df['BB_Position'] = (df['Close'] - df['BB_Lower']) / (df['BB_Upper'] - df['BB_Lower'])
    
    # ATR (Average True Range) - Volatilidade
    high_low = df['High'] - df['Low']
    high_close = np.abs(df['High'] - df['Close'].shift())
    low_close = np.abs(df['Low'] - df['Close'].shift())
    ranges = pd.concat([high_low, high_close, low_close], axis=1)
    true_range = ranges.max(axis=1)
    df['ATR'] = true_range.rolling(window=14).mean()
    
    # Retornos logarítmicos
    df['Log_Return'] = np.log(df['Close'] / df['Close'].shift(1))
    
    # Volatilidade histórica (20 dias)
    df['Volatility'] = df['Log_Return'].rolling(window=20).std() * np.sqrt(252)
    
    # Médias móveis como features
    df['SMA_10'] = df['Close'].rolling(window=10).mean()
    df['SMA_30'] = df['Close'].rolling(window=30).mean()
    df['EMA_10'] = df['Close'].ewm(span=10, adjust=False).mean()
    
    # Momentum
    df['Momentum_10'] = df['Close'] / df['Close'].shift(10) - 1
    
    # Volume normalizado
    df['Volume_Norm'] = df['Volume'] / df['Volume'].rolling(window=20).mean()
    
    # Price Rate of Change (ROC)
    df['ROC'] = (df['Close'] - df['Close'].shift(10)) / df['Close'].shift(10) * 100
    
    return df

# Aplica feature engineering
df = add_technical_indicators(df)

# Remove linhas com NaN (primeiras linhas devido aos indicadores)
df_clean = df.dropna()

print(f"Registros após feature engineering: {len(df_clean)}")
print(f"Features criadas: {len(df_clean.columns)}")
print(f"\nColunas disponíveis:")
print(df_clean.columns.tolist())
# Out:
# Registros após feature engineering: 1960
# Features criadas: 23
#
# Colunas disponíveis:
# ['Close', 'High', 'Low', 'Open', 'Volume', 'RSI', 'MACD', 'MACD_Signal', 'MACD_Hist', 'BB_Middle', 'BB_Upper', 'BB_Lower', 'BB_Width', 'BB_Position', 'ATR', 'Log_Return', 'Volatility', 'SMA_10', 'SMA_30', 'EMA_10', 'Momentum_10', 'Volume_Norm', 'ROC']

# %%
# Visualização dos indicadores técnicos
fig, axes = plt.subplots(4, 1, figsize=(14, 16))

# Preço com Bollinger Bands
axes[0].plot(df_clean.index, df_clean['Close'], label='Preço', color='#2196F3', linewidth=1.5)
axes[0].plot(df_clean.index, df_clean['BB_Upper'], label='BB Superior', color='#FF9800', linewidth=1, linestyle='--')
axes[0].plot(df_clean.index, df_clean['BB_Lower'], label='BB Inferior', color='#FF9800', linewidth=1, linestyle='--')
axes[0].fill_between(df_clean.index, df_clean['BB_Lower'], df_clean['BB_Upper'], alpha=0.1, color='#FF9800')
axes[0].set_title('Preço com Bollinger Bands', fontsize=12, fontweight='bold')
axes[0].legend(loc='upper left')
axes[0].grid(True, alpha=0.3)

# RSI
axes[1].plot(df_clean.index, df_clean['RSI'], color='#9C27B0', linewidth=1.5)
axes[1].axhline(y=70, color='red', linestyle='--', linewidth=1, label='Sobrecomprado')
axes[1].axhline(y=30, color='green', linestyle='--', linewidth=1, label='Sobrevendido')
axes[1].fill_between(df_clean.index, 30, 70, alpha=0.1, color='gray')
axes[1].set_title('RSI (Relative Strength Index)', fontsize=12, fontweight='bold')
axes[1].set_ylim(0, 100)
axes[1].legend(loc='upper left')
axes[1].grid(True, alpha=0.3)

# MACD
axes[2].plot(df_clean.index, df_clean['MACD'], label='MACD', color='#2196F3', linewidth=1.5)
axes[2].plot(df_clean.index, df_clean['MACD_Signal'], label='Signal', color='#FF5722', linewidth=1.5)
axes[2].bar(df_clean.index, df_clean['MACD_Hist'], label='Histograma', color='#4CAF50', alpha=0.5)
axes[2].axhline(y=0, color='black', linestyle='-', linewidth=0.5)
axes[2].set_title('MACD', fontsize=12, fontweight='bold')
axes[2].legend(loc='upper left')
axes[2].grid(True, alpha=0.3)

# Volatilidade
axes[3].plot(df_clean.index, df_clean['Volatility'] * 100, color='#F44336', linewidth=1.5)
axes[3].set_title('Volatilidade Anualizada (%)', fontsize=12, fontweight='bold')
axes[3].set_xlabel('Data')
axes[3].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('./data/technical_indicators.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 3. Análise Exploratória de Dados (EDA)
#
# Vamos analisar os padrões históricos dos preços da PETR4.SA.

# %%
# Gráfico de preços históricos
fig, axes = plt.subplots(3, 1, figsize=(14, 12))

# Preço de fechamento
axes[0].plot(df.index, df['Close'], color='#2196F3', linewidth=1.5)
axes[0].fill_between(df.index, df['Close'], alpha=0.3, color='#2196F3')
axes[0].set_title(f'Preço de Fechamento - {SYMBOL}', fontsize=14, fontweight='bold')
axes[0].set_ylabel('Preço (R$)')
axes[0].grid(True, alpha=0.3)

# Volume de negociação
axes[1].bar(df.index, df['Volume'], color='#4CAF50', alpha=0.7)
axes[1].set_title('Volume de Negociação', fontsize=14, fontweight='bold')
axes[1].set_ylabel('Volume')
axes[1].grid(True, alpha=0.3)

# Variação diária
df['Daily_Return'] = df['Close'].pct_change() * 100
axes[2].plot(df.index, df['Daily_Return'], color='#FF5722', linewidth=0.8, alpha=0.8)
axes[2].axhline(y=0, color='black', linestyle='-', linewidth=0.5)
axes[2].set_title('Retorno Diário (%)', fontsize=14, fontweight='bold')
axes[2].set_ylabel('Retorno (%)')
axes[2].set_xlabel('Data')
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('./data/price_analysis.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Médias móveis
df['MA_20'] = df['Close'].rolling(window=20).mean()
df['MA_50'] = df['Close'].rolling(window=50).mean()
df['MA_200'] = df['Close'].rolling(window=200).mean()

fig, ax = plt.subplots(figsize=(14, 6))

ax.plot(df.index, df['Close'], label='Preço', color='#2196F3', linewidth=1.5, alpha=0.8)
ax.plot(df.index, df['MA_20'], label='MM 20 dias', color='#FF9800', linewidth=1.2)
ax.plot(df.index, df['MA_50'], label='MM 50 dias', color='#4CAF50', linewidth=1.2)
ax.plot(df.index, df['MA_200'], label='MM 200 dias', color='#F44336', linewidth=1.2)

ax.set_title(f'Preço com Médias Móveis - {SYMBOL}', fontsize=14, fontweight='bold')
ax.set_xlabel('Data')
ax.set_ylabel('Preço (R$)')
ax.legend(loc='upper left')
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('./data/moving_averages.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Distribuição dos retornos
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Histograma
axes[0].hist(df['Daily_Return'].dropna(), bins=50, color='#2196F3', alpha=0.7, edgecolor='black')
axes[0].axvline(x=0, color='red', linestyle='--', linewidth=1.5)
axes[0].set_title('Distribuição dos Retornos Diários', fontsize=12, fontweight='bold')
axes[0].set_xlabel('Retorno (%)')
axes[0].set_ylabel('Frequência')

# Box plot por ano
df['Year'] = df.index.year
df.boxplot(column='Daily_Return', by='Year', ax=axes[1])
axes[1].set_title('Retornos por Ano', fontsize=12, fontweight='bold')
axes[1].set_xlabel('Ano')
axes[1].set_ylabel('Retorno (%)')
plt.suptitle('')  # Remove título automático

plt.tight_layout()
plt.savefig('./data/return_distribution.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 5. Pré-processamento dos Dados (Multivariado)
#
# ### Etapas:
# 1. Seleção das features mais relevantes
# 2. Divisão treino/teste (80/20) de forma **cronológica**
# 3. Normalização com **MinMaxScaler** (ajustado apenas no treino)
# 4. Criação de sequências temporais multivariadas

# %%
# Configurações do pré-processamento (OTIMIZADAS)
SEQUENCE_LENGTH = 60  # Aumentado para capturar padrões mais longos
TRAIN_RATIO = 0.80    # Mais dados para treino

# Seleção das features para o modelo
FEATURE_COLUMNS = [
    'Close',           # Target principal
    'RSI',             # Momentum
    'MACD',            # Tendência
    'MACD_Hist',       # Força da tendência
    'BB_Position',     # Posição nas bandas
    'BB_Width',        # Largura das bandas (volatilidade)
    'ATR',             # Volatilidade
    'Volatility',      # Volatilidade histórica
    'Momentum_10',     # Momentum 10 dias
    'Volume_Norm',     # Volume relativo
    'ROC',             # Rate of Change
    'Log_Return'       # Retorno logarítmico
]

# Extrai features selecionadas
features_df = df_clean[FEATURE_COLUMNS].copy()

print(f"Total de registros: {len(features_df)}")
print(f"Sequence length: {SEQUENCE_LENGTH}")
print(f"Train ratio: {TRAIN_RATIO}")
print(f"Número de features: {len(FEATURE_COLUMNS)}")
print(f"\nFeatures utilizadas:")
for i, col in enumerate(FEATURE_COLUMNS, 1):
    print(f"  {i}. {col}")
# Out:
# Total de registros: 1960
# Sequence length: 60
# Train ratio: 0.8
# Número de features: 12
#
# Features utilizadas:
#   1. Close
#   2. RSI
#   3. MACD
#   4. MACD_Hist
#   5. BB_Position
#   6. BB_Width
#   7. ATR
#   8. Volatility
#   9. Momentum_10
#   10. Volume_Norm
#   11. ROC
#   12. Log_Return

# %%
# Divisão cronológica treino/teste
# IMPORTANTE: Em séries temporais, NÃO embaralhamos os dados!
train_size = int(len(features_df) * TRAIN_RATIO)

train_data = features_df.iloc[:train_size].values
test_data = features_df.iloc[train_size:].values

# Guarda índices para visualização posterior
train_dates = df_clean.index[:train_size]
test_dates = df_clean.index[train_size:]

print(f"Dados de treino: {len(train_data)} registros")
print(f"Dados de teste: {len(test_data)} registros")
print(f"\nData de corte: {df_clean.index[train_size].date()}")
# Out:
# Dados de treino: 1568 registros
# Dados de teste: 392 registros
#
# Data de corte: 2024-06-11

# %%
# Normalização com MinMaxScaler para cada feature
# IMPORTANTE: Ajustar o scaler APENAS nos dados de treino para evitar data leakage

scaler_features = MinMaxScaler(feature_range=(0, 1))
scaler_target = MinMaxScaler(feature_range=(0, 1))

# Fit nos dados de treino
train_scaled = scaler_features.fit_transform(train_data)
test_scaled = scaler_features.transform(test_data)

# Scaler específico para o target (Close) - para inverse_transform depois
target_train = train_data[:, 0].reshape(-1, 1)  # Close é a primeira coluna
scaler_target.fit(target_train)

print(f"Scalers ajustados:")
print(f"  Features normalizadas: {len(FEATURE_COLUMNS)}")
print(f"  Range de Close: R$ {scaler_target.data_min_[0]:.2f} - R$ {scaler_target.data_max_[0]:.2f}")
# Out:
# Scalers ajustados:
#   Features normalizadas: 12
#   Range de Close: R$ 3.24 - R$ 32.78

# %%
def create_sequences_multivariate(data, sequence_length, target_col=0):
    """
    Cria sequências multivariadas para treinamento do LSTM.
    
    Args:
        data: Array com todas as features
        sequence_length: Número de timesteps
        target_col: Índice da coluna target (default=0 para Close)
    
    Returns:
        X: Sequências de features (samples, timesteps, features)
        y: Valores target (samples,)
    """
    X, y = [], []
    for i in range(sequence_length, len(data)):
        X.append(data[i-sequence_length:i, :])  # Todas as features
        y.append(data[i, target_col])           # Apenas o target
    
    return np.array(X), np.array(y)

# Cria sequências de treino
X_train, y_train = create_sequences_multivariate(train_scaled, SEQUENCE_LENGTH)

# Para o teste, incluímos parte do treino para formar as primeiras sequências
full_test = np.concatenate([train_scaled[-SEQUENCE_LENGTH:], test_scaled])
X_test, y_test = create_sequences_multivariate(full_test, SEQUENCE_LENGTH)

print(f"X_train shape: {X_train.shape}  (samples, timesteps, features)")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (1508, 60, 12)  (samples, timesteps, features)
# y_train shape: (1508,)
# X_test shape: (392, 60, 12)
# y_test shape: (392,)

# %% [markdown]
# ## 6. Construção do Modelo LSTM (Arquitetura Melhorada)
#
# ### Melhorias implementadas:
# - **Bidirectional LSTM**: Captura padrões em ambas as direções
# - **BatchNormalization**: Estabiliza o treinamento
# - **L2 Regularization**: Previne overfitting
# - **Gradient Clipping**: Evita gradientes explosivos
# - **Arquitetura mais profunda**: Melhor extração de features
#
# ### Hiperparâmetros otimizados:
# - LSTM units: [128, 64, 32]
# - Dropout rate: 0.3
# - L2 regularization: 0.001
# - Otimizador: Adam com clipnorm

# %%
from tensorflow.keras.layers import Bidirectional, BatchNormalization
from tensorflow.keras.regularizers import l2

def build_improved_lstm_model(sequence_length, n_features):
    """
    Constrói o modelo LSTM melhorado para previsão de preços.
    
    Melhorias:
    - Bidirectional LSTM para capturar padrões em ambas direções
    - BatchNormalization para estabilizar treinamento
    - L2 Regularization para prevenir overfitting
    - Dropout aumentado (0.3)
    """
    model = Sequential(name="Improved_LSTM_Stock_Predictor")
    
    # Camada de entrada
    model.add(Input(shape=(sequence_length, n_features)))
    
    # Primeira camada Bidirectional LSTM
    model.add(Bidirectional(
        LSTM(units=128, return_sequences=True, 
             kernel_regularizer=l2(0.001),
             recurrent_regularizer=l2(0.001)),
        name='bidirectional_lstm_1'
    ))
    model.add(BatchNormalization(name='bn_1'))
    model.add(Dropout(0.3, name='dropout_1'))
    
    # Segunda camada Bidirectional LSTM
    model.add(Bidirectional(
        LSTM(units=64, return_sequences=True,
             kernel_regularizer=l2(0.001),
             recurrent_regularizer=l2(0.001)),
        name='bidirectional_lstm_2'
    ))
    model.add(BatchNormalization(name='bn_2'))
    model.add(Dropout(0.3, name='dropout_2'))
    
    # Terceira camada LSTM (unidirecional para output)
    model.add(LSTM(units=32, return_sequences=False,
                   kernel_regularizer=l2(0.001),
                   name='lstm_3'))
    model.add(BatchNormalization(name='bn_3'))
    model.add(Dropout(0.3, name='dropout_3'))
    
    # Camadas Dense com regularização
    model.add(Dense(units=50, activation='relu', 
                    kernel_regularizer=l2(0.001),
                    name='dense_1'))
    model.add(Dropout(0.2, name='dropout_4'))
    
    model.add(Dense(units=25, activation='relu',
                    kernel_regularizer=l2(0.001),
                    name='dense_2'))
    
    # Camada de saída
    model.add(Dense(units=1, name='output'))
    
    # Compilação com gradient clipping
    model.compile(
        optimizer=Adam(learning_rate=0.001, clipnorm=1.0),
        loss='huber',  # Huber loss é mais robusto a outliers que MSE
        metrics=['mae']
    )
    
    return model

# Constrói o modelo com número correto de features
n_features = X_train.shape[2]
model = build_improved_lstm_model(SEQUENCE_LENGTH, n_features)
model.summary()

print(f"\n✓ Modelo construído com {n_features} features de entrada")
# Out:
# Model: "Improved_LSTM_Stock_Predictor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional_lstm_1            │ (None, 60, 256)        │       144,384 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_1 (BatchNormalization)       │ (None, 60, 256)        │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 60, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_lstm_2            │ (None, 60, 128)        │       164,352 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_2 (BatchNormalization)       │ (None, 60, 128)        │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 60, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 32)             │        20,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_3 (BatchNormalization)       │ (None, 32)             │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 50)             │         1,650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 333,959 (1.27 MB)
#  Trainable params: 333,127 (1.27 MB)
#  Non-trainable params: 832 (3.25 KB)
# ✓ Modelo construído com 12 features de entrada

# %% [markdown]
# ## 6. Treinamento do Modelo
#
# ### Callbacks:
# - **EarlyStopping**: Para o treinamento se val_loss não melhorar por 10 épocas
# - **ReduceLROnPlateau**: Reduz learning rate quando loss estagna
# - **ModelCheckpoint**: Salva o melhor modelo durante o treinamento

# %%
# Configurações de treinamento (OTIMIZADAS)
EPOCHS = 150          # Mais épocas com early stopping
BATCH_SIZE = 32

# Callbacks melhorados
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=15,              # Aumentado para dar mais tempo
        restore_best_weights=True,
        verbose=1,
        min_delta=0.0001          # Melhoria mínima requerida
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=7,
        min_lr=1e-7,
        verbose=1
    ),
    ModelCheckpoint(
        filepath='./data/best_model.keras',
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )
]

print(f"Configuração de treinamento:")
print(f"  Epochs: {EPOCHS}")
print(f"  Batch Size: {BATCH_SIZE}")
print(f"  Early Stopping Patience: 15")
print(f"  Learning Rate Reduction Patience: 7")
print("-" * 50)
# Out:
# Configuração de treinamento:
#   Epochs: 150
#   Batch Size: 32
#   Early Stopping Patience: 15
#   Learning Rate Reduction Patience: 7
# --------------------------------------------------

# %%
# Treinamento
history = model.fit(
    X_train, y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
    callbacks=callbacks,
    verbose=1
)

print("\n" + "=" * 50)
print("✓ Treinamento concluído!")
print(f"  Épocas executadas: {len(history.history['loss'])}")
print(f"  Melhor val_loss: {min(history.history['val_loss']):.6f}")
# Out:
# Epoch 1/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.3160 - mae: 0.4882
# Epoch 1: val_loss improved from None to 1.32732, saving model to ./data/best_model.keras
#
# Epoch 1: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - loss: 1.2034 - mae: 0.3827 - val_loss: 1.3273 - val_mae: 0.8212 - learning_rate: 0.0010
# Epoch 2/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.9873 - mae: 0.2192
# Epoch 2: val_loss improved from 1.32732 to 1.06114, saving model to ./data/best_model.keras
#
# Epoch 2: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 0.9454 - mae: 0.2153 - val_loss: 1.0611 - val_mae: 0.6882 - learning_rate: 0.0010
# Epoch 3/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.8223 - mae: 0.1967
# Epoch 3: val_loss improved from 1.06114 to 0.89014, saving model to ./data/best_model.keras
#
# Epoch 3: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.7898 - mae: 0.1924 - val_loss: 0.8901 - val_mae: 0.6262 - learning_rate: 0.0010
# Epoch 4/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.6916 - mae: 0.1724
# Epoch 4: val_loss improved from 0.89014 to 0.78268, saving model to ./data/best_model.keras
#
# Epoch 4: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.6651 - mae: 0.1661 - val_loss: 0.7827 - val_mae: 0.6213 - learning_rate: 0.0010
# Epoch 5/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.5859 - mae: 0.1451
# Epoch 5: val_loss improved from 0.78268 to 0.68978, saving model to ./data/best_model.keras
#
# Epoch 5: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.5644 - mae: 0.1404 - val_loss: 0.6898 - val_mae: 0.6070 - learning_rate: 0.0010
# Epoch 6/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.5007 - mae: 0.1271
# Epoch 6: val_loss improved from 0.68978 to 0.59949, saving model to ./data/best_model.keras
#
# Epoch 6: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.4830 - mae: 0.1230 - val_loss: 0.5995 - val_mae: 0.5731 - learning_rate: 0.0010
# Epoch 7/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4327 - mae: 0.1178
# Epoch 7: val_loss improved from 0.59949 to 0.49153, saving model to ./data/best_model.keras
#
# Epoch 7: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.4177 - mae: 0.1112 - val_loss: 0.4915 - val_mae: 0.4774 - learning_rate: 0.0010
# Epoch 8/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.3734 - mae: 0.1009
# Epoch 8: val_loss improved from 0.49153 to 0.44014, saving model to ./data/best_model.keras
#
# Epoch 8: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.3619 - mae: 0.1012 - val_loss: 0.4401 - val_mae: 0.4725 - learning_rate: 0.0010
# Epoch 9/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.3252 - mae: 0.0935
# Epoch 9: val_loss improved from 0.44014 to 0.40047, saving model to ./data/best_model.keras
#
# Epoch 9: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.3156 - mae: 0.0952 - val_loss: 0.4005 - val_mae: 0.4759 - learning_rate: 0.0010
# Epoch 10/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.2840 - mae: 0.0842
# Epoch 10: val_loss improved from 0.40047 to 0.35401, saving model to ./data/best_model.keras
#
# Epoch 10: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 0.2765 - mae: 0.0881 - val_loss: 0.3540 - val_mae: 0.4511 - learning_rate: 0.0010
# Epoch 11/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.2506 - mae: 0.0879
# Epoch 11: val_loss improved from 0.35401 to 0.32426, saving model to ./data/best_model.keras
#
# Epoch 11: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.2437 - mae: 0.0878 - val_loss: 0.3243 - val_mae: 0.4522 - learning_rate: 0.0010
# Epoch 12/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2212 - mae: 0.0829
# Epoch 12: val_loss improved from 0.32426 to 0.25641, saving model to ./data/best_model.keras
#
# Epoch 12: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.2153 - mae: 0.0832 - val_loss: 0.2564 - val_mae: 0.3473 - learning_rate: 0.0010
# Epoch 13/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1950 - mae: 0.0730
# Epoch 13: val_loss improved from 0.25641 to 0.21763, saving model to ./data/best_model.keras
#
# Epoch 13: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.1904 - mae: 0.0760 - val_loss: 0.2176 - val_mae: 0.2955 - learning_rate: 0.0010
# Epoch 14/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1738 - mae: 0.0735
# Epoch 14: val_loss improved from 0.21763 to 0.18048, saving model to ./data/best_model.keras
#
# Epoch 14: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.1691 - mae: 0.0734 - val_loss: 0.1805 - val_mae: 0.2268 - learning_rate: 0.0010
# Epoch 15/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1547 - mae: 0.0735
# Epoch 15: val_loss improved from 0.18048 to 0.16317, saving model to ./data/best_model.keras
#
# Epoch 15: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.1509 - mae: 0.0741 - val_loss: 0.1632 - val_mae: 0.2254 - learning_rate: 0.0010
# Epoch 16/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1377 - mae: 0.0674
# Epoch 16: val_loss improved from 0.16317 to 0.15701, saving model to ./data/best_model.keras
#
# Epoch 16: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.1345 - mae: 0.0682 - val_loss: 0.1570 - val_mae: 0.2612 - learning_rate: 0.0010
# Epoch 17/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1228 - mae: 0.0617
# Epoch 17: val_loss improved from 0.15701 to 0.14842, saving model to ./data/best_model.keras
#
# Epoch 17: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.1201 - mae: 0.0653 - val_loss: 0.1484 - val_mae: 0.2787 - learning_rate: 0.0010
# Epoch 18/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1101 - mae: 0.0622
# Epoch 18: val_loss improved from 0.14842 to 0.11192, saving model to ./data/best_model.keras
#
# Epoch 18: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.1077 - mae: 0.0646 - val_loss: 0.1119 - val_mae: 0.1657 - learning_rate: 0.0010
# Epoch 19/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0986 - mae: 0.0575
# Epoch 19: val_loss did not improve from 0.11192
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0966 - mae: 0.0603 - val_loss: 0.1219 - val_mae: 0.2607 - learning_rate: 0.0010
# Epoch 20/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0890 - mae: 0.0594
# Epoch 20: val_loss improved from 0.11192 to 0.10605, saving model to ./data/best_model.keras
#
# Epoch 20: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0869 - mae: 0.0607 - val_loss: 0.1061 - val_mae: 0.2318 - learning_rate: 0.0010
# Epoch 21/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0795 - mae: 0.0553
# Epoch 21: val_loss improved from 0.10605 to 0.09538, saving model to ./data/best_model.keras
#
# Epoch 21: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0779 - mae: 0.0574 - val_loss: 0.0954 - val_mae: 0.2191 - learning_rate: 0.0010
# Epoch 22/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0724 - mae: 0.0576
# Epoch 22: val_loss improved from 0.09538 to 0.07041, saving model to ./data/best_model.keras
#
# Epoch 22: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0705 - mae: 0.0574 - val_loss: 0.0704 - val_mae: 0.1130 - learning_rate: 0.0010
# Epoch 23/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0647 - mae: 0.0511
# Epoch 23: val_loss did not improve from 0.07041
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0635 - mae: 0.0545 - val_loss: 0.0782 - val_mae: 0.2024 - learning_rate: 0.0010
# Epoch 24/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0586 - mae: 0.0521
# Epoch 24: val_loss improved from 0.07041 to 0.06728, saving model to ./data/best_model.keras
#
# Epoch 24: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0574 - mae: 0.0532 - val_loss: 0.0673 - val_mae: 0.1730 - learning_rate: 0.0010
# Epoch 25/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0530 - mae: 0.0486
# Epoch 25: val_loss did not improve from 0.06728
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0522 - mae: 0.0519 - val_loss: 0.0710 - val_mae: 0.2175 - learning_rate: 0.0010
# Epoch 26/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0485 - mae: 0.0511
# Epoch 26: val_loss improved from 0.06728 to 0.05310, saving model to ./data/best_model.keras
#
# Epoch 26: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0477 - mae: 0.0527 - val_loss: 0.0531 - val_mae: 0.1446 - learning_rate: 0.0010
# Epoch 27/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0439 - mae: 0.0500
# Epoch 27: val_loss improved from 0.05310 to 0.04844, saving model to ./data/best_model.keras
#
# Epoch 27: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0432 - mae: 0.0517 - val_loss: 0.0484 - val_mae: 0.1370 - learning_rate: 0.0010
# Epoch 28/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0397 - mae: 0.0472
# Epoch 28: val_loss improved from 0.04844 to 0.04812, saving model to ./data/best_model.keras
#
# Epoch 28: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0392 - mae: 0.0505 - val_loss: 0.0481 - val_mae: 0.1610 - learning_rate: 0.0010
# Epoch 29/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0362 - mae: 0.0481
# Epoch 29: val_loss improved from 0.04812 to 0.03713, saving model to ./data/best_model.keras
#
# Epoch 29: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0356 - mae: 0.0495 - val_loss: 0.0371 - val_mae: 0.1032 - learning_rate: 0.0010
# Epoch 30/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0329 - mae: 0.0456
# Epoch 30: val_loss improved from 0.03713 to 0.03413, saving model to ./data/best_model.keras
#
# Epoch 30: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0327 - mae: 0.0497 - val_loss: 0.0341 - val_mae: 0.1007 - learning_rate: 0.0010
# Epoch 31/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0302 - mae: 0.0460
# Epoch 31: val_loss did not improve from 0.03413
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 0.0299 - mae: 0.0498 - val_loss: 0.0408 - val_mae: 0.1699 - learning_rate: 0.0010
# Epoch 32/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0277 - mae: 0.0462
# Epoch 32: val_loss improved from 0.03413 to 0.03038, saving model to ./data/best_model.keras
#
# Epoch 32: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 0.0273 - mae: 0.0481 - val_loss: 0.0304 - val_mae: 0.1123 - learning_rate: 0.0010
# Epoch 33/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0250 - mae: 0.0430
# Epoch 33: val_loss improved from 0.03038 to 0.02320, saving model to ./data/best_model.keras
#
# Epoch 33: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 0.0249 - mae: 0.0465 - val_loss: 0.0232 - val_mae: 0.0507 - learning_rate: 0.0010
# Epoch 34/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0233 - mae: 0.0459
# Epoch 34: val_loss did not improve from 0.02320
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0231 - mae: 0.0481 - val_loss: 0.0275 - val_mae: 0.1207 - learning_rate: 0.0010
# Epoch 35/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0212 - mae: 0.0442
# Epoch 35: val_loss improved from 0.02320 to 0.01924, saving model to ./data/best_model.keras
#
# Epoch 35: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 0.0210 - mae: 0.0459 - val_loss: 0.0192 - val_mae: 0.0449 - learning_rate: 0.0010
# Epoch 36/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0194 - mae: 0.0414
# Epoch 36: val_loss did not improve from 0.01924
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 0.0194 - mae: 0.0447 - val_loss: 0.0303 - val_mae: 0.1645 - learning_rate: 0.0010
# Epoch 37/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0179 - mae: 0.0430
# Epoch 37: val_loss did not improve from 0.01924
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - loss: 0.0178 - mae: 0.0461 - val_loss: 0.0213 - val_mae: 0.1080 - learning_rate: 0.0010
# Epoch 38/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0165 - mae: 0.0430
# Epoch 38: val_loss improved from 0.01924 to 0.01600, saving model to ./data/best_model.keras
#
# Epoch 38: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 0.0164 - mae: 0.0444 - val_loss: 0.0160 - val_mae: 0.0633 - learning_rate: 0.0010
# Epoch 39/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0149 - mae: 0.0393
# Epoch 39: val_loss improved from 0.01600 to 0.01311, saving model to ./data/best_model.keras
#
# Epoch 39: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0149 - mae: 0.0422 - val_loss: 0.0131 - val_mae: 0.0307 - learning_rate: 0.0010
# Epoch 40/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0139 - mae: 0.0430
# Epoch 40: val_loss did not improve from 0.01311
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0138 - mae: 0.0439 - val_loss: 0.0166 - val_mae: 0.0971 - learning_rate: 0.0010
# Epoch 41/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0133 - mae: 0.0443
# Epoch 41: val_loss improved from 0.01311 to 0.01103, saving model to ./data/best_model.keras
#
# Epoch 41: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0132 - mae: 0.0454 - val_loss: 0.0110 - val_mae: 0.0269 - learning_rate: 0.0010
# Epoch 42/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0125 - mae: 0.0444
# Epoch 42: val_loss improved from 0.01103 to 0.01053, saving model to ./data/best_model.keras
#
# Epoch 42: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 0.0124 - mae: 0.0456 - val_loss: 0.0105 - val_mae: 0.0334 - learning_rate: 0.0010
# Epoch 43/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0111 - mae: 0.0385
# Epoch 43: val_loss improved from 0.01053 to 0.00990, saving model to ./data/best_model.keras
#
# Epoch 43: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0111 - mae: 0.0409 - val_loss: 0.0099 - val_mae: 0.0390 - learning_rate: 0.0010
# Epoch 44/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0108 - mae: 0.0444
# Epoch 44: val_loss did not improve from 0.00990
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0105 - mae: 0.0450 - val_loss: 0.0142 - val_mae: 0.1052 - learning_rate: 0.0010
# Epoch 45/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0095 - mae: 0.0395
# Epoch 45: val_loss did not improve from 0.00990
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 0.0094 - mae: 0.0406 - val_loss: 0.0108 - val_mae: 0.0747 - learning_rate: 0.0010
# Epoch 46/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0091 - mae: 0.0413
# Epoch 46: val_loss improved from 0.00990 to 0.00795, saving model to ./data/best_model.keras
#
# Epoch 46: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0091 - mae: 0.0429 - val_loss: 0.0080 - val_mae: 0.0385 - learning_rate: 0.0010
# Epoch 47/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0083 - mae: 0.0391
# Epoch 47: val_loss did not improve from 0.00795
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0083 - mae: 0.0405 - val_loss: 0.0093 - val_mae: 0.0697 - learning_rate: 0.0010
# Epoch 48/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0078 - mae: 0.0395
# Epoch 48: val_loss improved from 0.00795 to 0.00779, saving model to ./data/best_model.keras
#
# Epoch 48: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0080 - mae: 0.0426 - val_loss: 0.0078 - val_mae: 0.0529 - learning_rate: 0.0010
# Epoch 49/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0075 - mae: 0.0394
# Epoch 49: val_loss improved from 0.00779 to 0.00697, saving model to ./data/best_model.keras
#
# Epoch 49: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0076 - mae: 0.0419 - val_loss: 0.0070 - val_mae: 0.0465 - learning_rate: 0.0010
# Epoch 50/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0071 - mae: 0.0405
# Epoch 50: val_loss did not improve from 0.00697
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0070 - mae: 0.0411 - val_loss: 0.0071 - val_mae: 0.0533 - learning_rate: 0.0010
# Epoch 51/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0065 - mae: 0.0394
# Epoch 51: val_loss improved from 0.00697 to 0.00564, saving model to ./data/best_model.keras
#
# Epoch 51: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0067 - mae: 0.0425 - val_loss: 0.0056 - val_mae: 0.0371 - learning_rate: 0.0010
# Epoch 52/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0062 - mae: 0.0390
# Epoch 52: val_loss improved from 0.00564 to 0.00483, saving model to ./data/best_model.keras
#
# Epoch 52: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0063 - mae: 0.0409 - val_loss: 0.0048 - val_mae: 0.0252 - learning_rate: 0.0010
# Epoch 53/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0061 - mae: 0.0399
# Epoch 53: val_loss did not improve from 0.00483
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 0.0064 - mae: 0.0429 - val_loss: 0.0063 - val_mae: 0.0566 - learning_rate: 0.0010
# Epoch 54/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0055 - mae: 0.0369
# Epoch 54: val_loss improved from 0.00483 to 0.00464, saving model to ./data/best_model.keras
#
# Epoch 54: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 0.0056 - mae: 0.0395 - val_loss: 0.0046 - val_mae: 0.0339 - learning_rate: 0.0010
# Epoch 55/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0053 - mae: 0.0384
# Epoch 55: val_loss did not improve from 0.00464
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0055 - mae: 0.0412 - val_loss: 0.0049 - val_mae: 0.0427 - learning_rate: 0.0010
# Epoch 56/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0052 - mae: 0.0396
# Epoch 56: val_loss improved from 0.00464 to 0.00424, saving model to ./data/best_model.keras
#
# Epoch 56: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0052 - mae: 0.0406 - val_loss: 0.0042 - val_mae: 0.0345 - learning_rate: 0.0010
# Epoch 57/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0050 - mae: 0.0395
# Epoch 57: val_loss did not improve from 0.00424
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0053 - mae: 0.0427 - val_loss: 0.0092 - val_mae: 0.1029 - learning_rate: 0.0010
# Epoch 58/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0049 - mae: 0.0398
# Epoch 58: val_loss did not improve from 0.00424
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0049 - mae: 0.0403 - val_loss: 0.0081 - val_mae: 0.0944 - learning_rate: 0.0010
# Epoch 59/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0049 - mae: 0.0434
# Epoch 59: val_loss improved from 0.00424 to 0.00363, saving model to ./data/best_model.keras
#
# Epoch 59: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 0.0052 - mae: 0.0452 - val_loss: 0.0036 - val_mae: 0.0274 - learning_rate: 0.0010
# Epoch 60/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0044 - mae: 0.0390
# Epoch 60: val_loss did not improve from 0.00363
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0045 - mae: 0.0408 - val_loss: 0.0045 - val_mae: 0.0500 - learning_rate: 0.0010
# Epoch 61/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0040 - mae: 0.0367
# Epoch 61: val_loss did not improve from 0.00363
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0042 - mae: 0.0388 - val_loss: 0.0057 - val_mae: 0.0732 - learning_rate: 0.0010
# Epoch 62/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0038 - mae: 0.0366
# Epoch 62: val_loss did not improve from 0.00363
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0040 - mae: 0.0385 - val_loss: 0.0037 - val_mae: 0.0420 - learning_rate: 0.0010
# Epoch 63/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0037 - mae: 0.0379
# Epoch 63: val_loss did not improve from 0.00363
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0039 - mae: 0.0404 - val_loss: 0.0047 - val_mae: 0.0624 - learning_rate: 0.0010
# Epoch 64/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0041 - mae: 0.0407
# Epoch 64: val_loss did not improve from 0.00363
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 0.0043 - mae: 0.0435 - val_loss: 0.0048 - val_mae: 0.0629 - learning_rate: 0.0010
# Epoch 65/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0041 - mae: 0.0399
# Epoch 65: val_loss improved from 0.00363 to 0.00340, saving model to ./data/best_model.keras
#
# Epoch 65: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0043 - mae: 0.0428 - val_loss: 0.0034 - val_mae: 0.0383 - learning_rate: 0.0010
# Epoch 66/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0036 - mae: 0.0370
# Epoch 66: val_loss did not improve from 0.00340
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 0.0037 - mae: 0.0388 - val_loss: 0.0039 - val_mae: 0.0521 - learning_rate: 0.0010
# Epoch 67/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0034 - mae: 0.0374
# Epoch 67: val_loss did not improve from 0.00340
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0035 - mae: 0.0392 - val_loss: 0.0050 - val_mae: 0.0699 - learning_rate: 0.0010
# Epoch 68/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0032 - mae: 0.0375
# Epoch 68: val_loss did not improve from 0.00340
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 0.0033 - mae: 0.0393 - val_loss: 0.0057 - val_mae: 0.0808 - learning_rate: 0.0010
# Epoch 69/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0032 - mae: 0.0373
# Epoch 69: val_loss improved from 0.00340 to 0.00296, saving model to ./data/best_model.keras
#
# Epoch 69: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 0.0035 - mae: 0.0408 - val_loss: 0.0030 - val_mae: 0.0393 - learning_rate: 0.0010
# Epoch 70/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0029 - mae: 0.0346
# Epoch 70: val_loss improved from 0.00296 to 0.00279, saving model to ./data/best_model.keras
#
# Epoch 70: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 0.0030 - mae: 0.0371 - val_loss: 0.0028 - val_mae: 0.0380 - learning_rate: 0.0010
# Epoch 71/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0035 - mae: 0.0410
# Epoch 71: val_loss improved from 0.00279 to 0.00272, saving model to ./data/best_model.keras
#
# Epoch 71: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 0.0036 - mae: 0.0426 - val_loss: 0.0027 - val_mae: 0.0364 - learning_rate: 0.0010
# Epoch 72/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0031 - mae: 0.0373
# Epoch 72: val_loss did not improve from 0.00272
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 0.0031 - mae: 0.0383 - val_loss: 0.0029 - val_mae: 0.0399 - learning_rate: 0.0010
# Epoch 73/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0029 - mae: 0.0367
# Epoch 73: val_loss did not improve from 0.00272
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 0.0033 - mae: 0.0409 - val_loss: 0.0027 - val_mae: 0.0383 - learning_rate: 0.0010
# Epoch 74/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0028 - mae: 0.0360
# Epoch 74: val_loss improved from 0.00272 to 0.00209, saving model to ./data/best_model.keras
#
# Epoch 74: finished saving model to ./data/best_model.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 0.0030 - mae: 0.0385 - val_loss: 0.0021 - val_mae: 0.0280 - learning_rate: 0.0010
# Epoch 75/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0030 - mae: 0.0378
# Epoch 75: val_loss did not improve from 0.00209
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - loss: 0.0032 - mae: 0.0407 - val_loss: 0.0044 - val_mae: 0.0692 - learning_rate: 0.0010
# Epoch 76/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0040 - mae: 0.0451
# Epoch 76: val_loss did not improve from 0.00209
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0043 - mae: 0.0453 - val_loss: 0.0033 - val_mae: 0.0409 - learning_rate: 0.0010
# Epoch 77/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0039 - mae: 0.0399
# Epoch 77: val_loss did not improve from 0.00209
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 0.0042 - mae: 0.0436 - val_loss: 0.0100 - val_mae: 0.1191 - learning_rate: 0.0010
# Epoch 78/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0034 - mae: 0.0394
# Epoch 78: val_loss did not improve from 0.00209
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0037 - mae: 0.0428 - val_loss: 0.0052 - val_mae: 0.0739 - learning_rate: 0.0010
# Epoch 79/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0031 - mae: 0.0378
# Epoch 79: val_loss did not improve from 0.00209
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0032 - mae: 0.0397 - val_loss: 0.0077 - val_mae: 0.1030 - learning_rate: 0.0010
# Epoch 80/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0027 - mae: 0.0373
# Epoch 80: val_loss did not improve from 0.00209
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0028 - mae: 0.0393 - val_loss: 0.0070 - val_mae: 0.0990 - learning_rate: 0.0010
# Epoch 81/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0025 - mae: 0.0359
# Epoch 81: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 81: val_loss did not improve from 0.00209
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0027 - mae: 0.0378 - val_loss: 0.0072 - val_mae: 0.1011 - learning_rate: 0.0010
# Epoch 82/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0024 - mae: 0.0357
# Epoch 82: val_loss did not improve from 0.00209
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0027 - mae: 0.0388 - val_loss: 0.0049 - val_mae: 0.0754 - learning_rate: 5.0000e-04
# Epoch 83/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0025 - mae: 0.0366
# Epoch 83: val_loss did not improve from 0.00209
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 0.0027 - mae: 0.0385 - val_loss: 0.0040 - val_mae: 0.0642 - learning_rate: 5.0000e-04
# Epoch 84/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0023 - mae: 0.0341
# Epoch 84: val_loss did not improve from 0.00209
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0025 - mae: 0.0359 - val_loss: 0.0042 - val_mae: 0.0679 - learning_rate: 5.0000e-04
# Epoch 85/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0022 - mae: 0.0322
# Epoch 85: val_loss did not improve from 0.00209
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 0.0024 - mae: 0.0353 - val_loss: 0.0036 - val_mae: 0.0595 - learning_rate: 5.0000e-04
# Epoch 86/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0021 - mae: 0.0330
# Epoch 86: val_loss did not improve from 0.00209
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 0.0023 - mae: 0.0343 - val_loss: 0.0038 - val_mae: 0.0631 - learning_rate: 5.0000e-04
# Epoch 87/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0022 - mae: 0.0338
# Epoch 87: val_loss did not improve from 0.00209
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0023 - mae: 0.0350 - val_loss: 0.0025 - val_mae: 0.0435 - learning_rate: 5.0000e-04
# Epoch 88/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0020 - mae: 0.0323
# Epoch 88: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 88: val_loss did not improve from 0.00209
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0021 - mae: 0.0339 - val_loss: 0.0031 - val_mae: 0.0539 - learning_rate: 5.0000e-04
# Epoch 89/150
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0020 - mae: 0.0319
# Epoch 89: val_loss did not improve from 0.00209
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0021 - mae: 0.0342 - val_loss: 0.0024 - val_mae: 0.0426 - learning_rate: 2.5000e-04
# Epoch 89: early stopping
# Restoring model weights from the end of the best epoch: 74.
#
# ==================================================
# ✓ Treinamento concluído!
#   Épocas executadas: 89
#   Melhor val_loss: 0.002088

# %%
# Visualização do treinamento
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Loss
axes[0].plot(history.history['loss'], label='Treino', linewidth=2)
axes[0].plot(history.history['val_loss'], label='Validação', linewidth=2)
axes[0].set_title('Evolução do Loss (MSE)', fontsize=12, fontweight='bold')
axes[0].set_xlabel('Época')
axes[0].set_ylabel('Loss')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# MAE
axes[1].plot(history.history['mae'], label='Treino', linewidth=2)
axes[1].plot(history.history['val_mae'], label='Validação', linewidth=2)
axes[1].set_title('Evolução do MAE', fontsize=12, fontweight='bold')
axes[1].set_xlabel('Época')
axes[1].set_ylabel('MAE')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('./data/training_history.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 7. Avaliação do Modelo
#
# ### Métricas utilizadas:
# - **MAE** (Mean Absolute Error): Erro médio em R$
# - **RMSE** (Root Mean Square Error): Penaliza erros maiores
# - **MAPE** (Mean Absolute Percentage Error): Erro percentual médio
# - **R²** (Coeficiente de Determinação): Variância explicada pelo modelo

# %%
# Predições no conjunto de teste
y_pred_scaled = model.predict(X_test, verbose=0)

# Reverte normalização usando o scaler do target
y_pred = scaler_target.inverse_transform(y_pred_scaled).flatten()
y_true = scaler_target.inverse_transform(y_test.reshape(-1, 1)).flatten()

print(f"Predições realizadas: {len(y_pred)}")
# Out:
# Predições realizadas: 392

# %%
# Cálculo das métricas
def calculate_mape(y_true, y_pred):
    """Calcula MAPE evitando divisão por zero."""
    mask = y_true != 0
    return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100

mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mape = calculate_mape(y_true, y_pred)
r2 = r2_score(y_true, y_pred)

# Armazena métricas
metrics = {
    'mae': float(mae),
    'rmse': float(rmse),
    'mape': float(mape),
    'r2': float(r2)
}

print("=" * 60)
print("           MÉTRICAS DE AVALIAÇÃO DO MODELO")
print("=" * 60)
print(f"\n  MAE  (Erro Absoluto Médio):      R$ {mae:.2f}")
print(f"  RMSE (Raiz Erro Quadrático):     R$ {rmse:.2f}")
print(f"  MAPE (Erro Percentual Médio):       {mape:.2f}%")
print(f"  R²   (Coef. Determinação):          {r2:.4f}")
print("\n" + "=" * 60)

# Classificação do MAPE
if mape < 10:
    mape_class = "EXCELENTE"
elif mape < 20:
    mape_class = "BOM"
elif mape < 50:
    mape_class = "RAZOÁVEL"
else:
    mape_class = "IMPRECISO"

print(f"\n  📊 Classificação do modelo (MAPE): {mape_class}")
print(f"  📈 O modelo explica {r2*100:.1f}% da variância dos preços")
# Out:
# ============================================================
#            MÉTRICAS DE AVALIAÇÃO DO MODELO
# ============================================================
#
#   MAE  (Erro Absoluto Médio):      R$ 0.83
#   RMSE (Raiz Erro Quadrático):     R$ 1.05
#   MAPE (Erro Percentual Médio):       2.65%
#   R²   (Coef. Determinação):          0.5476
#
# ============================================================
#
#   📊 Classificação do modelo (MAPE): EXCELENTE
#   📈 O modelo explica 54.8% da variância dos preços

# %%
# Visualização: Valores Reais vs Preditos
fig, axes = plt.subplots(2, 1, figsize=(14, 10))

# As predições correspondem exatamente às datas de teste
# (full_test já inclui os dados de treino necessários para formar as sequências iniciais)
plot_dates = test_dates

axes[0].plot(plot_dates, y_true, label='Valor Real', color='#2196F3', linewidth=1.5)
axes[0].plot(plot_dates, y_pred, label='Predição', color='#FF5722', linewidth=1.5, linestyle='--')
axes[0].set_title(f'Previsão de Preços - {SYMBOL} (Modelo Melhorado)', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Data')
axes[0].set_ylabel('Preço (R$)')
axes[0].legend(loc='upper left')
axes[0].grid(True, alpha=0.3)

# Scatter plot
axes[1].scatter(y_true, y_pred, alpha=0.5, color='#2196F3')
axes[1].plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'r--', linewidth=2, label='Ideal')
axes[1].set_title('Valores Reais vs Preditos', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Valor Real (R$)')
axes[1].set_ylabel('Valor Predito (R$)')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('./data/predictions_vs_actual.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Análise dos erros
errors = y_true - y_pred
plot_dates = test_dates

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Distribuição dos erros
axes[0].hist(errors, bins=50, color='#2196F3', alpha=0.7, edgecolor='black')
axes[0].axvline(x=0, color='red', linestyle='--', linewidth=2)
axes[0].set_title('Distribuição dos Erros de Predição', fontsize=12, fontweight='bold')
axes[0].set_xlabel('Erro (R$)')
axes[0].set_ylabel('Frequência')

# Erros ao longo do tempo
axes[1].plot(plot_dates, errors, color='#FF5722', linewidth=0.8, alpha=0.8)
axes[1].axhline(y=0, color='black', linestyle='-', linewidth=0.5)
axes[1].fill_between(plot_dates, errors, alpha=0.3, color='#FF5722')
axes[1].set_title('Erros ao Longo do Tempo', fontsize=12, fontweight='bold')
axes[1].set_xlabel('Data')
axes[1].set_ylabel('Erro (R$)')

plt.tight_layout()
plt.savefig('./data/error_analysis.png', dpi=150, bbox_inches='tight')
plt.show()

print(f"\nEstatísticas dos Erros:")
print(f"  Média: R$ {errors.mean():.2f}")
print(f"  Desvio Padrão: R$ {errors.std():.2f}")
print(f"  Mínimo: R$ {errors.min():.2f}")
print(f"  Máximo: R$ {errors.max():.2f}")
# Out:
# Estatísticas dos Erros:
#   Média: R$ 0.31
#   Desvio Padrão: R$ 1.00
#   Mínimo: R$ -2.20
#   Máximo: R$ 3.05

# %% [markdown]
# ## 8. Salvamento do Modelo
#
# Exportamos o modelo treinado e o scaler para uso na API.

# %%
# Cria diretório de modelos se não existir
os.makedirs('../models', exist_ok=True)

# Salva o modelo
MODEL_PATH = '../models/lstm_model.keras'
model.save(MODEL_PATH)
print(f"✓ Modelo salvo em: {MODEL_PATH}")

# Salva os scalers
SCALER_FEATURES_PATH = '../models/scaler_features.pkl'
SCALER_TARGET_PATH = '../models/scaler.pkl'  # Mantém compatibilidade com API

joblib.dump(scaler_features, SCALER_FEATURES_PATH)
joblib.dump(scaler_target, SCALER_TARGET_PATH)
print(f"✓ Scaler de features salvo em: {SCALER_FEATURES_PATH}")
print(f"✓ Scaler de target salvo em: {SCALER_TARGET_PATH}")

# Salva lista de features usadas
FEATURES_PATH = '../models/feature_columns.json'
with open(FEATURES_PATH, 'w') as f:
    json.dump(FEATURE_COLUMNS, f)
print(f"✓ Lista de features salva em: {FEATURES_PATH}")
# Out:
# ✓ Modelo salvo em: ../models/lstm_model.keras
# ✓ Scaler de features salvo em: ../models/scaler_features.pkl
# ✓ Scaler de target salvo em: ../models/scaler.pkl
# ✓ Lista de features salva em: ../models/feature_columns.json

# %%
# Salva resultados do treinamento
training_results = {
    "symbol": SYMBOL,
    "training_start": START_DATE,
    "training_end": datetime.now().isoformat(),
    "model_version": "2.0_improved",
    "parameters": {
        "sequence_length": SEQUENCE_LENGTH,
        "train_ratio": TRAIN_RATIO,
        "epochs_configured": EPOCHS,
        "epochs_run": len(history.history['loss']),
        "batch_size": BATCH_SIZE,
        "architecture": "Bidirectional LSTM + BatchNorm + L2 Reg",
        "lstm_units": [128, 64, 32],
        "dropout_rate": 0.3,
        "learning_rate": 0.001,
        "loss_function": "huber",
        "l2_regularization": 0.001,
        "gradient_clipping": 1.0
    },
    "features": {
        "columns": FEATURE_COLUMNS,
        "n_features": len(FEATURE_COLUMNS)
    },
    "data_info": {
        "total_records": len(df_clean),
        "train_records": len(train_data),
        "test_records": len(test_data),
        "price_min": float(df_clean['Close'].min()),
        "price_max": float(df_clean['Close'].max()),
        "price_mean": float(df_clean['Close'].mean())
    },
    "training_history": {
        "final_loss": float(history.history['loss'][-1]),
        "final_val_loss": float(history.history['val_loss'][-1]),
        "best_val_loss": float(min(history.history['val_loss']))
    },
    "evaluation_metrics": metrics,
    "saved_files": {
        "model": MODEL_PATH,
        "scaler_features": SCALER_FEATURES_PATH,
        "scaler_target": SCALER_TARGET_PATH,
        "feature_columns": FEATURES_PATH
    }
}

# Salva JSON
RESULTS_PATH = '../models/training_results.json'
with open(RESULTS_PATH, 'w', encoding='utf-8') as f:
    json.dump(training_results, f, indent=2, ensure_ascii=False)

print(f"✓ Resultados salvos em: {RESULTS_PATH}")
# Out:
# ✓ Resultados salvos em: ../models/training_results.json

# %% [markdown]
# ## 9. Resumo Final
#
# ### Resultados do Treinamento

# %%
print("\n" + "=" * 70)
print("              RESUMO DO TREINAMENTO (MODELO MELHORADO)")
print("=" * 70)
print(f"\n  📊 Ação: {SYMBOL}")
print(f"  📅 Período: {START_DATE} até {END_DATE}")
print(f"  📈 Total de registros: {len(df_clean)}")
print(f"\n  🔧 Configurações:")
print(f"     - Sequence Length: {SEQUENCE_LENGTH} dias")
print(f"     - Train/Test Split: {int(TRAIN_RATIO*100)}/{int((1-TRAIN_RATIO)*100)}")
print(f"     - Épocas executadas: {len(history.history['loss'])}")
print(f"     - Features utilizadas: {len(FEATURE_COLUMNS)}")
print(f"\n  🏗️ Arquitetura:")
print(f"     - Bidirectional LSTM + BatchNormalization")
print(f"     - L2 Regularization (0.001)")
print(f"     - Dropout: 0.3")
print(f"     - Loss: Huber (robusta a outliers)")
print(f"\n  📉 Métricas de Avaliação:")
print(f"     - MAE:  R$ {mae:.2f}")
print(f"     - RMSE: R$ {rmse:.2f}")
print(f"     - MAPE: {mape:.2f}%")
print(f"     - R²:   {r2:.4f}")
print(f"\n  💾 Arquivos salvos:")
print(f"     - {MODEL_PATH}")
print(f"     - {SCALER_FEATURES_PATH}")
print(f"     - {SCALER_TARGET_PATH}")
print(f"     - {RESULTS_PATH}")
print("\n" + "=" * 70)
print("           ✅ TREINAMENTO CONCLUÍDO COM SUCESSO!")
print("=" * 70)
# Out:
# ======================================================================
#               RESUMO DO TREINAMENTO (MODELO MELHORADO)
# ======================================================================
#
#   📊 Ação: PETR4.SA
#   📅 Período: 2018-01-01 até 2026-01-05
#   📈 Total de registros: 1960
#
#   🔧 Configurações:
#      - Sequence Length: 60 dias
#      - Train/Test Split: 80/19
#      - Épocas executadas: 89
#      - Features utilizadas: 12
#
#   🏗️ Arquitetura:
#      - Bidirectional LSTM + BatchNormalization
#      - L2 Regularization (0.001)
#      - Dropout: 0.3
#      - Loss: Huber (robusta a outliers)
#
#   📉 Métricas de Avaliação:
#      - MAE:  R$ 0.83
#      - RMSE: R$ 1.05
#      - MAPE: 2.65%
#      - R²:   0.5476
#
#   💾 Arquivos salvos:
#      - ../models/lstm_model.keras
#      - ../models/scaler_features.pkl
#      - ../models/scaler.pkl
#      - ../models/training_results.json
#
# ======================================================================
#            ✅ TREINAMENTO CONCLUÍDO COM SUCESSO!
# ======================================================================

# %% [markdown]
# ---
#
# ## 📝 Notas para Demonstração em Vídeo
#
# ### Tópicos a abordar:
#
# 1. **Introdução**
#    - Apresentação do problema: previsão de preços de ações
#    - Por que LSTM? Memória de longo prazo para séries temporais
#
# 2. **Coleta de Dados**
#    - Uso do Yahoo Finance via yfinance
#    - Empresa escolhida: Petrobras (PETR4.SA)
#
# 3. **Pré-processamento**
#    - Importância da normalização para redes neurais
#    - Split cronológico (não aleatório!) para séries temporais
#    - Criação de sequências de 60 dias
#
# 4. **Arquitetura do Modelo**
#    - 3 camadas LSTM com Dropout
#    - Explicar return_sequences
#    - Total de parâmetros treináveis
#
# 5. **Treinamento**
#    - Callbacks: EarlyStopping e ReduceLROnPlateau
#    - Evolução do loss
#
# 6. **Avaliação**
#    - Métricas: MAE, RMSE, MAPE, R²
#    - Interpretação dos resultados
#    - Gráfico de predições vs reais
#
# 7. **API em Funcionamento**
#    - Demonstrar endpoints /predict e /health
#    - Mostrar Swagger UI (/docs)
#    - Fazer predição em tempo real
#
# 8. **Monitoramento**
#    - Dashboard Grafana
#    - Métricas Prometheus
#
# ---
